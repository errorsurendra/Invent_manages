# %%
import joblib
import pandas as pd

model = joblib.load("models/demand_model.pkl")

sample = pd.DataFrame({
    "Amount":[4500],
    "Product_ID":[3],
    "Country_ID":[1],
    "Salesperson_ID":[4],
    "Year":[2022],
    "Month":[7],
    "Day":[20],
    "Day_of_Week":[2],
    "Quarter":[3],
    "Weekend":[0],
    "Revenue_per_Box":[18],
    "Lag_1":[200],
    "Lag_7":[180],
    "Rolling_7":[195],
    "Rolling_30":[210]
})

prediction = model.predict(sample)

print("Predicted Boxes Shipped:")

print(round(prediction[0]))
# Out:
# Predicted Boxes Shipped:
# 252
